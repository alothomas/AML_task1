# %% [markdown]
# # Imports and paths configuration

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# c:\Users\alois\Desktop\Advanced ML\AML_Task_1

# %%
import sys
import os
import yaml
from ax.service.ax_client import AxClient
from task1.src.train import main
from task1.utils import unflatten_dict

# %%
with open('task1/config/default_train_config_mice.yaml', 'r') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# # Parameters choice

# %%
parameters = [
    {
        "name": "miceV2.estimator_params.n_estimators",
        "type": "range",
        "bounds": [50, 200],
        "value_type": 'int'
    },
    {
        "name": "miceV2.estimator_params.max_depth",
        "type": 'range',
        'bounds': [2, 10],
        'value_type': 'int'
    },
    {
        'name': 'miceV2.mice_params.max_iter',
        'type': 'range',
        'bounds': [5, 20],
        'value_type': 'int'
    },
    {
        'name': 'miceV2.num_corr_features',
        'type': 'range',
        'bounds': [0.1, 0.9],
        'value_type': 'float'
    },
    {
        "name": "lasso_alpha", 
        "type": "range", 
        "bounds": [0, 10],
        "value_type": 'int'
    },
    {
        "name": "ridge_alpha",
        "type": "range",
        "bounds": [0, 10],
        "value_type": 'int'        
    },
    {
        "name": "gamma",
        "type": "range",
        "bounds": [0.001, 0.01],
        "value_type": 'float'
    },
    {
        "name": "miceV2.simple_params.strategy",
        "type": "choice",
        "values": ["mean", "median", "most_frequent", "constant"],
    },
    {
        "name": "miceV2.mice_params.imputation_order",
        "type": "choice",
        "values": ["ascending", "descending", "roman", "arabic", "random"],
    },
]

# %% [markdown]
# # Tuning

# %%
def evaluate_model(parameters):
    # Change any default config here:
    config['train']['model_type'] = 'krr'
    
    # Parse parameters
    config['train']['preprocessing']['feature_selection']['arguments']['alpha'] = parameters['lasso_alpha']/10
    config['train']['model_config']['alpha'] = parameters['ridge_alpha']/10
    config['train']['model_config']['gamma'] = parameters['gamma']

    config['train']['preprocessing']['imputation']['method'] = 'miceV2'
    config['train']['preprocessing']['imputation']['arguments'] = {}
    config['train']['preprocessing']['imputation']['arguments']['estimator_params'] = {}
    config['train']['preprocessing']['imputation']['arguments']['mice_params'] = {}
    config['train']['preprocessing']['imputation']['arguments']['simple_params'] = {}
    config['train']['preprocessing']['imputation']['arguments']['num_corr_features'] = parameters['miceV2.num_corr_features']


    
    # Parse parameters
    for param_name in parameters:
        param_value = parameters[param_name]
        if param_name.startswith('miceV2.'):
            param_name_split = param_name.split('.')
            if len(param_name_split) == 3:
                config['train']['preprocessing']['imputation']['arguments'][param_name_split[1]][param_name_split[2]] = param_value
            elif len(param_name_split) == 4:
                config['train']['preprocessing']['imputation']['arguments'][param_name_split[1]][param_name_split[2]][param_name_split[3]] = param_value
        else:
            #config['train']['preprocessing']['imputation']['arguments'][param_name] = param_value
            print("no arg to parse")
    print(config)
    
    return main(config)

# %%
ax_client = AxClient()
objective_name = 'preprocessing_tune'
ax_client.create_experiment(
    parameters=parameters,
    objective_name=objective_name,
    minimize=False
)

# Specify the initial parameters according to your configuration
initial_parameters = {
    "miceV2.estimator_params.n_estimators": 100,  # You can set the initial values as needed
    "miceV2.estimator_params.max_depth": 5,
    "miceV2.mice_params.max_iter": 10,
    "miceV2.num_corr_features": 0.5,
    "lasso_alpha": 5,
    "ridge_alpha": 5,
    "gamma": 0.005,
    "miceV2.simple_params.strategy": "mean",  # Choose a strategy from your configuration
    "miceV2.mice_params.imputation_order": "descending"
}

_, trial_id = ax_client.attach_trial(initial_parameters)
ax_client.complete_trial(trial_id, raw_data=evaluate_model(initial_parameters))



for i in range(10):    
    curr_parameters, trial_index = ax_client.get_next_trial()
    ax_client.complete_trial(trial_index=trial_index, raw_data=evaluate_model(curr_parameters))
# Out:
# [INFO 11-08 23:00:45] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 11-08 23:00:45] ax.service.utils.instantiation: Inferred value type of ParameterType.STRING for parameter miceV2.simple_params.strategy. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# c:\Users\alois\anaconda3\Lib\site-packages\ax\core\parameter.py:517: UserWarning: `is_ordered` is not specified for `ChoiceParameter` "miceV2.simple_params.strategy". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `is_ordered` during `ChoiceParameter` construction.
#   warn(
# c:\Users\alois\anaconda3\Lib\site-packages\ax\core\parameter.py:517: UserWarning: `sort_values` is not specified for `ChoiceParameter` "miceV2.simple_params.strategy". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `sort_values` during `ChoiceParameter` construction.
#   warn(
# [INFO 11-08 23:00:45] ax.service.utils.instantiation: Inferred value type of ParameterType.STRING for parameter miceV2.mice_params.imputation_order. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# c:\Users\alois\anaconda3\Lib\site-packages\ax\core\parameter.py:517: UserWarning: `is_ordered` is not specified for `ChoiceParameter` "miceV2.mice_params.imputation_order". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `is_ordered` during `ChoiceParameter` construction.
#   warn(
# c:\Users\alois\anaconda3\Lib\site-packages\ax\core\parameter.py:517: UserWarning: `sort_values` is not specified for `ChoiceParameter` "miceV2.mice_params.imputation_order". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `sort_values` during `ChoiceParameter` construction.
#   warn(
# [INFO 11-08 23:00:45] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='miceV2.estimator_params.n_estimators', parameter_type=INT, range=[50, 200]), RangeParameter(name='miceV2.estimator_params.max_depth', parameter_type=INT, range=[2, 10]), RangeParameter(name='miceV2.mice_params.max_iter', parameter_type=INT, range=[5, 20]), RangeParameter(name='miceV2.num_corr_features', parameter_type=FLOAT, range=[0.1, 0.9]), RangeParameter(name='lasso_alpha', parameter_type=INT, range=[0, 10]), RangeParameter(name='ridge_alpha', parameter_type=INT, range=[0, 10]), RangeParameter(name='gamma', parameter_type=FLOAT, range=[0.001, 0.01]), ChoiceParameter(name='miceV2.simple_params.strategy', parameter_type=STRING, values=['mean', 'median', 'most_frequent', 'constant'], is_ordered=False, sort_values=False), ChoiceParameter(name='miceV2.mice_params.imputation_order', parameter_type=STRING, values=['ascending', 'descending', 'roman', 'arabic', 'random'], is_ordered=False, sort_values=False)], parameter_constraints=[]).
# [INFO 11-08 23:00:45] ax.modelbridge.dispatch_utils: Using Bayesian optimization with a categorical kernel for improved performance with a large number of unordered categorical parameters.
# [INFO 11-08 23:00:45] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=9 num_trials=None use_batch_trials=False
# [INFO 11-08 23:00:45] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=18
# [INFO 11-08 23:00:45] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=18
# [INFO 11-08 23:00:45] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BO_MIXED', steps=[Sobol for 18 trials, BO_MIXED for subsequent trials]). Iterations after 18 will take longer to generate due to model-fitting.
# [INFO 11-08 23:00:45] ax.core.experiment: Attached custom parameterizations [{'miceV2.estimator_params.n_estimators': 100, 'miceV2.estimator_params.max_depth': 5, 'miceV2.mice_params.max_iter': 10, 'miceV2.num_corr_features': 0.5, 'lasso_alpha': 5, 'ridge_alpha': 5, 'gamma': 0.005, 'miceV2.simple_params.strategy': 'mean', 'miceV2.mice_params.imputation_order': 'descending'}] as trial 0.
# no arg to parse
# no arg to parse
# no arg to parse
# {'train': {'data_paths': {'features': 'data/X_train.csv', 'label': 'data/y_train.csv'}, 'preprocessing': {'scale': True, 'imputation': {'method': 'miceV2', 'arguments': {'estimator_params': {'n_estimators': 100, 'max_depth': 5}, 'mice_params': {'max_iter': 10, 'imputation_order': 'descending'}, 'simple_params': {'strategy': 'mean'}, 'num_corr_features': 0.5}}, 'outliers_detection': {'method': 'isolation_forest', 'arguments': {}}, 'feature_selection': {'method': 'lasso', 'arguments': {'alpha': 0.5}}, 'execution_order': ['imputation', 'outliers_detection', 'feature_selection']}, 'model_type': 'krr', 'model_config': {'kernel': 'rbf', 'gamma': 0.005, 'alpha': 0.5}, 'cross_validation': 5, 'results_path': 'results/overview.csv'}, 'evaluate': {'run': True, 'data_paths': {'features': 'data/X_test.csv', 'label': 'data/y_test_rbf.csv'}}}
# 225

# %% [markdown]
# # Get best config and write prediction data

# %%
import pandas as pd
results_path = 'results/overview.csv'
# Remove duplicates results, should fix this in train.py
pd.read_csv(results_path).sort_values(by='train_results', ascending=False).drop_duplicates().to_csv(results_path, index=False)
results = pd.read_csv(results_path).sort_values(by='train_results', ascending=False).drop_duplicates().reset_index(drop=True)

# %%
results
# Out:
#    train/data_paths/features train/data_paths/label  \
# 0           data/X_train.csv       data/y_train.csv
# 1           data/X_train.csv       data/y_train.csv
# 2           data/X_train.csv       data/y_train.csv
# 3           data/X_train.csv       data/y_train.csv
# 4           data/X_train.csv       data/y_train.csv
# 5           data/X_train.csv       data/y_train.csv
# 6           data/X_train.csv       data/y_train.csv
# 7           data/X_train.csv       data/y_train.csv
# 8           data/X_train.csv       data/y_train.csv
# 9           data/X_train.csv       data/y_train.csv
# 10          data/X_train.csv       data/y_train.csv
# 11          data/X_train.csv       data/y_train.csv
# 12          data/X_train.csv       data/y_train.csv
# 13          data/X_train.csv       data/y_train.csv
# 14          data/X_train.csv       data/y_train.csv
# 15          data/X_train.csv       data/y_train.csv
# 16          data/X_train.csv       data/y_train.csv
# 17          data/X_train.csv       data/y_train.csv
# 18          data/X_train.csv       data/y_train.csv
# 19          data/X_train.csv       data/y_train.csv
# 20          data/X_train.csv       data/y_train.csv
# 21          data/X_train.csv       data/y_train.csv
# 22          data/X_train.csv       data/y_train.csv
# 23          data/X_train.csv       data/y_train.csv
# 24          data/X_train.csv       data/y_train.csv
# 25          data/X_train.csv       data/y_train.csv
# 26          data/X_train.csv       data/y_train.csv
# 27          data/X_train.csv       data/y_train.csv
# 28          data/X_train.csv       data/y_train.csv
# 29          data/X_train.csv       data/y_train.csv
# 30          data/X_train.csv       data/y_train.csv
# 31          data/X_train.csv       data/y_train.csv
# 32          data/X_train.csv       data/y_train.csv
# 33          data/X_train.csv       data/y_train.csv
# 34          data/X_train.csv       data/y_train.csv
# 35          data/X_train.csv       data/y_train.csv
# 36          data/X_train.csv       data/y_train.csv
# 37          data/X_train.csv       data/y_train.csv
# 38          data/X_train.csv       data/y_train.csv
# 39          data/X_train.csv       data/y_train.csv
# 40          data/X_train.csv       data/y_train.csv
# 41          data/X_train.csv       data/y_train.csv
# 42          data/X_train.csv       data/y_train.csv
# 43          data/X_train.csv       data/y_train.csv
# 44          data/X_train.csv       data/y_train.csv
# 45          data/X_train.csv       data/y_train.csv
# 46          data/X_train.csv       data/y_train.csv
# 47          data/X_train.csv       data/y_train.csv
# 48          data/X_train.csv       data/y_train.csv
# 49          data/X_train.csv       data/y_train.csv
# 50          data/X_train.csv       data/y_train.csv
# 51          data/X_train.csv       data/y_train.csv
# 52          data/X_train.csv       data/y_train.csv
# 53          data/X_train.csv       data/y_train.csv
# 54          data/X_train.csv       data/y_train.csv
# 55          data/X_train.csv       data/y_train.csv
# 56          data/X_train.csv       data/y_train.csv
# 57          data/X_train.csv       data/y_train.csv
# 58          data/X_train.csv       data/y_train.csv
# 59          data/X_train.csv       data/y_train.csv
#
#     train/preprocessing/scale train/preprocessing/imputation/method  \
# 0                        True                                  mice
# 1                        True                                  mice
# 2                        True                                  mice
# 3                        True                                  mice
# 4                        True                                  mice
# 5                        True                                  mice
# 6                        True                                  mice
# 7                        True                                  mice
# 8                        True                                  mice
# 9                        True                                  mice
# 10                       True                                  mice
# 11                       True                                  mice
# 12                       True                                  mice
# 13                       True                                  mice
# 14                       True                                  mice
# 15                       True                                  mice
# 16                       True                                  mice
# 17                       True                                  mice
# 18                       True                                  mice
# 19                       True                                  mice
# 20                       True                                  mice
# 21                       True                                  mice
# 22                       True                                  mice
# 23                       True                                  mice
# 24                       True                                  mice
# 25                       True                                  mice
# 26                       True                                  mice
# 27                       True                                  mice
# 28                       True                                  mice
# 29                       True                                  mice
# 30                       True                                  mice
# 31                       True                                  mice
# 32                       True                                  mice
# 33                       True                                  mice
# 34                       True                                  mice
# 35                       True                                  mice
# 36                       True                                  mice
# 37                       True                                  mice
# 38                       True                                  mice
# 39                       True                                  mice
# 40                       True                                  mice
# 41                       True                                  mice
# 42                       True                                  mice
# 43                       True                                  mice
# 44                       True                                  mice
# 45                       True                                  mice
# 46                       True                                  mice
# 47                       True                                  mice
# 48                       True                                  mice
# 49                       True                                  mice
# 50                       True                                  mice
# 51                       True                                  mice
# 52                       True                                  mice
# 53                       True                                  mice
# 54                       True                                  mice
# 55                       True                                  mice
# 56                       True                                  mice
# 57                       True                                  mice
# 58                       True                                  mice
# 59                       True                                  mice
#
#     train/preprocessing/imputation/arguments/estimator_params/n_estimators  \
# 0                                               200.0
# 1                                               200.0
# 2                                               174.0
# 3                                               134.0
# 4                                               167.0
# 5                                               119.0
# 6                                               152.0
# 7                                               134.0
# 8                                               130.0
# 9                                                91.0
# 10                                               50.0
# 11                                              113.0
# 12                                               50.0
# 13                                               50.0
# 14                                              197.0
# 15                                              136.0
# 16                                               65.0
# 17                                               86.0
# 18                                               80.0
# 19                                               96.0
# 20                                               50.0
# 21                                              100.0
# 22                                              100.0
# 23                                              139.0
# 24                                               78.0
# 25                                              200.0
# 26                                              103.0
# 27                                              164.0
# 28                                              200.0
# 29                                              143.0
# 30                                              109.0
# 31                                               50.0
# 32                                              200.0
# 33                                               50.0
# 34                                               50.0
# 35                                              200.0
# 36                                              150.0
# 37                                               66.0
# 38                                              103.0
# 39                                              200.0
# 40                                               92.0
# 41                                              113.0
# 42                                              192.0
# 43                                              149.0
# 44                                              131.0
# 45                                              122.0
# 46                                               53.0
# 47                                               63.0
# 48                                               50.0
# 49                                              193.0
# 50                                              144.0
# 51                                               69.0
# 52                                              117.0
# 53                                               50.0
# 54                                              196.0
# 55                                              121.0
# 56                                              200.0
# 57                                               50.0
# 58                                                NaN
# 59                                                NaN
#
#     train/preprocessing/imputation/arguments/estimator_params/max_depth  \
# 0                                                 9.0
# 1                                                 2.0
# 2                                                 7.0
# 3                                                10.0
# 4                                                 9.0
# 5                                                 2.0
# 6                                                 2.0
# 7                                                 7.0
# 8                                                 7.0
# 9                                                 2.0
# 10                                                6.0
# 11                                                5.0
# 12                                                9.0
# 13                                                2.0
# 14                                                2.0
# 15                                                6.0
# 16                                               10.0
# 17                                                4.0
# 18                                                5.0
# 19                                                6.0
# 20                                                8.0
# 21                                                5.0
# 22                                                5.0
# 23                                                3.0
# 24                                                2.0
# 25                                               10.0
# 26                                                7.0
# 27                                                2.0
# 28                                                9.0
# 29                                                2.0
# 30                                                2.0
# 31                                                4.0
# 32                                                6.0
# 33                                               10.0
# 34                                                6.0
# 35                                               10.0
# 36                                                5.0
# 37                                                4.0
# 38                                               10.0
# 39                                                4.0
# 40                                                9.0
# 41                                                7.0
# 42                                                7.0
# 43                                                5.0
# 44                                               10.0
# 45                                                8.0
# 46                                                7.0
# 47                                                7.0
# 48                                                8.0
# 49                                                7.0
# 50                                                3.0
# 51                                               10.0
# 52                                                4.0
# 53                                                7.0
# 54                                                4.0
# 55                                                3.0
# 56                                               10.0
# 57                                                2.0
# 58                                                NaN
# 59                                                NaN
#
#     train/preprocessing/imputation/arguments/mice_params/max_iter  \
# 0                                                 6.0
# 1                                                 8.0
# 2                                                 7.0
# 3                                                 5.0
# 4                                                 9.0
# 5                                                16.0
# 6                                                 8.0
# 7                                                20.0
# 8                                                 5.0
# 9                                                 9.0
# 10                                                5.0
# 11                                               18.0
# 12                                               11.0
# 13                                               19.0
# 14                                                5.0
# 15                                                7.0
# 16                                               11.0
# 17                                               15.0
# 18                                               20.0
# 19                                               17.0
# 20                                                5.0
# 21                                               10.0
# 22                                               10.0
# 23                                               17.0
# 24                                               17.0
# 25                                                9.0
# 26                                               11.0
# 27                                               15.0
# 28                                                5.0
# 29                                               19.0
# 30                                                6.0
# 31                                               18.0
# 32                                               20.0
# 33                                                8.0
# 34                                                5.0
# 35                                               20.0
# 36                                                7.0
# 37                                               14.0
# 38                                               20.0
# 39                                                5.0
# 40                                                8.0
# 41                                               10.0
# 42                                               20.0
# 43                                               13.0
# 44                                               17.0
# 45                                               15.0
# 46                                                6.0
# 47                                               11.0
# 48                                               20.0
# 49                                               20.0
# 50                                               14.0
# 51                                               20.0
# 52                                               12.0
# 53                                               13.0
# 54                                               11.0
# 55                                               17.0
# 56                                               20.0
# 57                                               19.0
# 58                                                NaN
# 59                                                NaN
#
#    train/preprocessing/imputation/arguments/mice_params/imputation_order  \
# 0                                          descending
# 1                                           ascending
# 2                                           ascending
# 3                                           ascending
# 4                                              arabic
# 5                                          descending
# 6                                              arabic
# 7                                           ascending
# 8                                          descending
# 9                                          descending
# 10                                         descending
# 11                                          ascending
# 12                                             arabic
# 13                                          ascending
# 14                                          ascending
# 15                                         descending
# 16                                         descending
# 17                                         descending
# 18                                          ascending
# 19                                         descending
# 20                                         descending
# 21                                         descending
# 22                                         descending
# 23                                         descending
# 24                                          ascending
# 25                                          ascending
# 26                                             arabic
# 27                                             random
# 28                                             random
# 29                                          ascending
# 30                                          ascending
# 31                                             random
# 32                                          ascending
# 33                                             arabic
# 34                                          ascending
# 35                                              roman
# 36                                              roman
# 37                                         descending
# 38                                         descending
# 39                                             random
# 40                                             random
# 41                                          ascending
# 42                                         descending
# 43                                             random
# 44                                              roman
# 45                                             random
# 46                                             random
# 47                                         descending
# 48                                             random
# 49                                             arabic
# 50                                             arabic
# 51                                             random
# 52                                             random
# 53                                          ascending
# 54                                         descending
# 55                                             arabic
# 56                                             random
# 57                                             arabic
# 58                                                NaN
# 59                                                NaN
#
#    train/preprocessing/imputation/arguments/simple_params/strategy  \
# 0                                                mean
# 1                                                mean
# 2                                                mean
# 3                                              median
# 4                                            constant
# 5                                                mean
# 6                                              median
# 7                                                mean
# 8                                            constant
# 9                                            constant
# 10                                           constant
# 11                                               mean
# 12                                           constant
# 13                                               mean
# 14                                               mean
# 15                                           constant
# 16                                             median
# 17                                           constant
# 18                                               mean
# 19                                             median
# 20                                               mean
# 21                                               mean
# 22                                               mean
# 23                                           constant
# 24                                               mean
# 25                                               mean
# 26                                               mean
# 27                                             median
# 28                                           constant
# 29                                           constant
# 30                                           constant
# 31                                             median
# 32                                               mean
# 33                                           constant
# 34                                           constant
# 35                                               mean
# 36                                      most_frequent
# 37                                           constant
# 38                                      most_frequent
# 39                                      most_frequent
# 40                                      most_frequent
# 41                                               mean
# 42                                      most_frequent
# 43                                               mean
# 44                                           constant
# 45                                           constant
# 46                                             median
# 47                                               mean
# 48                                           constant
# 49                                             median
# 50                                      most_frequent
# 51                                           constant
# 52                                             median
# 53                                      most_frequent
# 54                                      most_frequent
# 55                                      most_frequent
# 56                                           constant
# 57                                           constant
# 58                                                NaN
# 59                                                NaN
#
#     train/preprocessing/imputation/arguments/num_corr_features  ...  \
# 0                                                12.0           ...
# 1                                                 5.0           ...
# 2                                                12.0           ...
# 3                                                 7.0           ...
# 4                                                15.0           ...
# 5                                                 5.0           ...
# 6                                                 7.0           ...
# 7                                                15.0           ...
# 8                                                14.0           ...
# 9                                                 5.0           ...
# 10                                               12.0           ...
# 11                                               14.0           ...
# 12                                               13.0           ...
# 13                                                5.0           ...
# 14                                                5.0           ...
# 15                                               13.0           ...
# 16                                               14.0           ...
# 17                                                8.0           ...
# 18                                               15.0           ...
# 19                                               13.0           ...
# 20                                                7.0           ...
# 21                                               10.0           ...
# 22                                               10.0           ...
# 23                                                8.0           ...
# 24                                                9.0           ...
# 25                                               11.0           ...
# 26                                               15.0           ...
# 27                                               12.0           ...
# 28                                               15.0           ...
# 29                                                5.0           ...
# 30                                               15.0           ...
# 31                                                5.0           ...
# 32                                                6.0           ...
# 33                                               15.0           ...
# 34                                               10.0           ...
# 35                                               15.0           ...
# 36                                               11.0           ...
# 37                                               10.0           ...
# 38                                               12.0           ...
# 39                                               11.0           ...
# 40                                                7.0           ...
# 41                                               12.0           ...
# 42                                               12.0           ...
# 43                                               14.0           ...
# 44                                               13.0           ...
# 45                                               13.0           ...
# 46                                                8.0           ...
# 47                                               12.0           ...
# 48                                               15.0           ...
# 49                                                8.0           ...
# 50                                               11.0           ...
# 51                                               11.0           ...
# 52                                               11.0           ...
# 53                                                6.0           ...
# 54                                                9.0           ...
# 55                                               11.0           ...
# 56                                               15.0           ...
# 57                                                5.0           ...
# 58                                                NaN           ...
# 59                                                NaN           ...
#
#    train/model_type train/model_config/kernel  train/model_config/gamma  \
# 0               krr                       rbf                  0.004307
# 1               krr                       rbf                  0.006216
# 2               krr                       rbf                  0.006247
# 3               krr                       rbf                  0.006037
# 4               krr                       rbf                  0.004635
# 5               krr                       rbf                  0.004141
# 6               krr                       rbf                  0.004696
# 7               krr                       rbf                  0.004570
# 8               krr                       rbf                  0.002951
# 9               krr                       rbf                  0.005537
# 10              krr                       rbf                  0.006071
# 11              krr                       rbf                  0.002807
# 12              krr                       rbf                  0.003876
# 13              krr                       rbf                  0.004029
# 14              krr                       rbf                  0.007506
# 15              krr                       rbf                  0.003924
# 16              krr                       rbf                  0.007817
# 17              krr                       rbf                  0.002626
# 18              krr                       rbf                  0.006850
# 19              krr                       rbf                  0.002843
# 20              krr                       rbf                  0.009088
# 21              krr                       rbf                  0.005000
# 22              krr                       rbf                  0.005000
# 23              krr                       rbf                  0.001436
# 24              krr                       rbf                  0.005516
# 25              krr                       rbf                  0.001724
# 26              krr                       rbf                  0.001932
# 27              krr                       rbf                  0.006091
# 28              krr                       rbf                  0.001550
# 29              krr                       rbf                  0.001000
# 30              krr                       rbf                  0.001000
# 31              krr                       rbf                  0.001000
# 32              krr                       rbf                  0.001152
# 33              krr                       rbf                  0.001110
# 34              krr                       rbf                  0.001000
# 35              krr                       rbf                  0.001000
# 36              krr                       rbf                  0.001996
# 37              krr                       rbf                  0.007786
# 38              krr                       rbf                  0.001532
# 39              krr                       rbf                  0.001000
# 40              krr                       rbf                  0.003431
# 41              krr                       rbf                  0.009006
# 42              krr                       rbf                  0.003667
# 43              krr                       rbf                  0.009349
# 44              krr                       rbf                  0.006407
# 45              krr                       rbf                  0.006863
# 46              krr                       rbf                  0.006300
# 47              krr                       rbf                  0.006999
# 48              krr                       rbf                  0.010000
# 49              krr                       rbf                  0.008711
# 50              krr                       rbf                  0.002668
# 51              krr                       rbf                  0.004636
# 52              krr                       rbf                  0.004902
# 53              krr                       rbf                  0.010000
# 54              krr                       rbf                  0.004450
# 55              krr                       rbf                  0.007052
# 56              krr                       rbf                  0.001000
# 57              krr                       rbf                  0.009450
# 58              krr                       NaN                       NaN
# 59              krr                       NaN                       NaN
#
#    train/model_config/alpha train/cross_validation    train/results_path  \
# 0                       0.1                    5.0  results/overview.csv
# 1                       0.2                    5.0  results/overview.csv
# 2                       0.1                    5.0  results/overview.csv
# 3                       0.2                    5.0  results/overview.csv
# 4                       0.1                    5.0  results/overview.csv
# 5                       0.4                    5.0  results/overview.csv
# 6                       0.7                    5.0  results/overview.csv
# 7                       0.4                    5.0  results/overview.csv
# 8                       0.2                    5.0  results/overview.csv
# 9                       0.7                    5.0  results/overview.csv
# 10                      0.3                    5.0  results/overview.csv
# 11                      0.3                    5.0  results/overview.csv
# 12                      0.6                    5.0  results/overview.csv
# 13                      0.7                    5.0  results/overview.csv
# 14                      0.1                    5.0  results/overview.csv
# 15                      0.9                    5.0  results/overview.csv
# 16                      0.7                    5.0  results/overview.csv
# 17                      0.4                    5.0  results/overview.csv
# 18                      0.4                    5.0  results/overview.csv
# 19                      0.9                    5.0  results/overview.csv
# 20                      0.1                    5.0  results/overview.csv
# 21                      0.5                    5.0  results/overview.csv
# 22                      0.5                    5.0  results/overview.csv
# 23                      0.2                    5.0  results/overview.csv
# 24                      0.3                    5.0  results/overview.csv
# 25                      0.4                    5.0  results/overview.csv
# 26                      0.8                    5.0  results/overview.csv
# 27                      0.3                    5.0  results/overview.csv
# 28                      0.9                    5.0  results/overview.csv
# 29                      0.5                    5.0  results/overview.csv
# 30                      1.0                    5.0  results/overview.csv
# 31                      0.8                    5.0  results/overview.csv
# 32                      1.0                    5.0  results/overview.csv
# 33                      0.5                    5.0  results/overview.csv
# 34                      1.0                    5.0  results/overview.csv
# 35                      1.0                    5.0  results/overview.csv
# 36                      0.1                    5.0  results/overview.csv
# 37                      0.8                    5.0  results/overview.csv
# 38                      0.4                    5.0  results/overview.csv
# 39                      0.3                    5.0  results/overview.csv
# 40                      1.0                    5.0  results/overview.csv
# 41                      0.7                    5.0  results/overview.csv
# 42                      0.9                    5.0  results/overview.csv
# 43                      0.7                    5.0  results/overview.csv
# 44                      1.0                    5.0  results/overview.csv
# 45                      0.2                    5.0  results/overview.csv
# 46                      0.1                    5.0  results/overview.csv
# 47                      0.0                    5.0  results/overview.csv
# 48                      0.0                    5.0  results/overview.csv
# 49                      0.1                    5.0  results/overview.csv
# 50                      0.0                    5.0  results/overview.csv
# 51                      0.9                    5.0  results/overview.csv
# 52                      0.3                    5.0  results/overview.csv
# 53                      0.3                    5.0  results/overview.csv
# 54                      0.1                    5.0  results/overview.csv
# 55                      0.0                    5.0  results/overview.csv
# 56                      0.0                    5.0  results/overview.csv
# 57                      0.4                    5.0  results/overview.csv
# 58                      NaN                    5.0  results/overview.csv
# 59                      NaN                    5.0  results/overview.csv
#
#     evaluate/run  evaluate/data_paths/features  evaluate/data_paths/label  \
# 0           True               data/X_test.csv        data/y_test_rbf.csv
# 1           True               data/X_test.csv        data/y_test_rbf.csv
# 2           True               data/X_test.csv        data/y_test_rbf.csv
# 3           True               data/X_test.csv        data/y_test_rbf.csv
# 4           True               data/X_test.csv        data/y_test_rbf.csv
# 5           True               data/X_test.csv        data/y_test_rbf.csv
# 6           True               data/X_test.csv        data/y_test_rbf.csv
# 7           True               data/X_test.csv        data/y_test_rbf.csv
# 8           True               data/X_test.csv        data/y_test_rbf.csv
# 9           True               data/X_test.csv        data/y_test_rbf.csv
# 10          True               data/X_test.csv        data/y_test_rbf.csv
# 11          True               data/X_test.csv        data/y_test_rbf.csv
# 12          True               data/X_test.csv        data/y_test_rbf.csv
# 13          True               data/X_test.csv        data/y_test_rbf.csv
# 14          True               data/X_test.csv        data/y_test_rbf.csv
# 15          True               data/X_test.csv        data/y_test_rbf.csv
# 16          True               data/X_test.csv        data/y_test_rbf.csv
# 17          True               data/X_test.csv        data/y_test_rbf.csv
# 18          True               data/X_test.csv        data/y_test_rbf.csv
# 19          True               data/X_test.csv        data/y_test_rbf.csv
# 20          True               data/X_test.csv        data/y_test_rbf.csv
# 21          True               data/X_test.csv        data/y_test_rbf.csv
# 22          True               data/X_test.csv        data/y_test_rbf.csv
# 23          True               data/X_test.csv        data/y_test_rbf.csv
# 24          True               data/X_test.csv        data/y_test_rbf.csv
# 25          True               data/X_test.csv        data/y_test_rbf.csv
# 26          True               data/X_test.csv        data/y_test_rbf.csv
# 27          True               data/X_test.csv        data/y_test_rbf.csv
# 28          True               data/X_test.csv        data/y_test_rbf.csv
# 29          True               data/X_test.csv        data/y_test_rbf.csv
# 30          True               data/X_test.csv        data/y_test_rbf.csv
# 31          True               data/X_test.csv        data/y_test_rbf.csv
# 32          True               data/X_test.csv        data/y_test_rbf.csv
# 33          True               data/X_test.csv        data/y_test_rbf.csv
# 34          True               data/X_test.csv        data/y_test_rbf.csv
# 35          True               data/X_test.csv        data/y_test_rbf.csv
# 36          True               data/X_test.csv        data/y_test_rbf.csv
# 37          True               data/X_test.csv        data/y_test_rbf.csv
# 38          True               data/X_test.csv        data/y_test_rbf.csv
# 39          True               data/X_test.csv        data/y_test_rbf.csv
# 40          True               data/X_test.csv        data/y_test_rbf.csv
# 41          True               data/X_test.csv        data/y_test_rbf.csv
# 42          True               data/X_test.csv        data/y_test_rbf.csv
# 43          True               data/X_test.csv        data/y_test_rbf.csv
# 44          True               data/X_test.csv        data/y_test_rbf.csv
# 45          True               data/X_test.csv        data/y_test_rbf.csv
# 46          True               data/X_test.csv        data/y_test_rbf.csv
# 47          True               data/X_test.csv        data/y_test_rbf.csv
# 48          True               data/X_test.csv        data/y_test_rbf.csv
# 49          True               data/X_test.csv        data/y_test_rbf.csv
# 50          True               data/X_test.csv        data/y_test_rbf.csv
# 51          True               data/X_test.csv        data/y_test_rbf.csv
# 52          True               data/X_test.csv        data/y_test_rbf.csv
# 53          True               data/X_test.csv        data/y_test_rbf.csv
# 54          True               data/X_test.csv        data/y_test_rbf.csv
# 55          True               data/X_test.csv        data/y_test_rbf.csv
# 56          True               data/X_test.csv        data/y_test_rbf.csv
# 57          True               data/X_test.csv        data/y_test_rbf.csv
# 58          True               data/X_test.csv        Data/y_test_rbf.csv
# 59          True               data/X_test.csv        Data/y_test_rbf.csv
#
#    train_results
# 0       0.449828
# 1       0.449525
# 2       0.444121
# 3       0.443323
# 4       0.441701
# 5       0.438186
# 6       0.435585
# 7       0.435293
# 8       0.431519
# 9       0.430190
# 10      0.427068
# 11      0.426889
# 12      0.426835
# 13      0.425790
# 14      0.421651
# 15      0.417088
# 16      0.413265
# 17      0.413201
# 18      0.409127
# 19      0.406654
# 20      0.403058
# 21      0.397171
# 22      0.395271
# 23      0.392407
# 24      0.391646
# 25      0.390993
# 26      0.383597
# 27      0.378323
# 28      0.374115
# 29      0.370152
# 30      0.369261
# 31      0.368237
# 32      0.367848
# 33      0.363904
# 34      0.361725
# 35      0.357010
# 36      0.348884
# 37      0.328725
# 38      0.322439
# 39      0.273981
# 40      0.209883
# 41      0.168698
# 42      0.162789
# 43      0.143819
# 44      0.048730
# 45      0.024493
# 46      0.024298
# 47     -0.029702
# 48     -0.046002
# 49     -0.209819
# 50     -0.722402
# 51     -1.122765
# 52     -1.163973
# 53     -1.265277
# 54     -1.866830
# 55     -6.136740
# 56     -7.880099
# 57    -51.369771
# 58    -53.083867
# 59    -53.274306
#
# [60 rows x 24 columns]

# %%
best_param_dct_linear = results[results['train/model_type'] == 'krr'].iloc[0].to_dict()
del best_param_dct_linear['train_results']

# %%
best_param_dct_linear
# Out:
# {'train/data_paths/features': 'data/X_train.csv',
#  'train/data_paths/label': 'data/y_train.csv',
#  'train/preprocessing/scale': True,
#  'train/preprocessing/imputation/method': 'mice',
#  'train/preprocessing/imputation/arguments/estimator_params/n_estimators': 200.0,
#  'train/preprocessing/imputation/arguments/estimator_params/max_depth': 9.0,
#  'train/preprocessing/imputation/arguments/mice_params/max_iter': 6.0,
#  'train/preprocessing/imputation/arguments/mice_params/imputation_order': 'descending',
#  'train/preprocessing/imputation/arguments/simple_params/strategy': 'mean',
#  'train/preprocessing/imputation/arguments/num_corr_features': 12.0,
#  'train/preprocessing/outliers_detection/method': 'isolation_forest',
#  'train/preprocessing/feature_selection/method': 'lasso',
#  'train/preprocessing/feature_selection/arguments/alpha': 1.0,
#  'train/preprocessing/execution_order': 'imputation; outliers_detection; feature_selection',
#  'train/model_type': 'krr',
#  'train/model_config/kernel': 'rbf',
#  'train/model_config/gamma': 0.0043072457731913,
#  'train/model_config/alpha': 0.1,
#  'train/cross_validation': 5.0,
#  'train/results_path': 'results/overview.csv',
#  'evaluate/run': True,
#  'evaluate/data_paths/features': 'data/X_test.csv',
#  'evaluate/data_paths/label': 'data/y_test_rbf.csv'}

# %%
best_param_config = unflatten_dict(best_param_dct_linear)
best_param_config['evaluate']['data_paths']['label'] = 'Data/y_test_rbf_miceV2.csv'
best_param_config['evaluate']['run'] = True
best_param_config['train']['model_config'] = {}
best_param_config['train']['preprocessing']['outliers_detection']['arguments'] = {}

best_param_config['train']['preprocessing']['feature_selection']['arguments']['alpha'] = {}
best_param_config['train']['model_config']['alpha'] = {}
best_param_config['train']['model_config']['gamma'] = {}

best_param_config['train']['preprocessing']['imputation']['method'] = 'miceV2'
best_param_config['train']['preprocessing']['imputation']['arguments'] = {}
best_param_config['train']['preprocessing']['imputation']['arguments']['estimator_params'] = {}
best_param_config['train']['preprocessing']['imputation']['arguments']['mice_params'] = {}
best_param_config['train']['preprocessing']['imputation']['arguments']['simple_params'] = {}
best_param_config['train']['preprocessing']['imputation']['arguments']['num_corr_features'] = {}


    
# Parse parameters
for param_name in parameters:
    param_value = best_param_config[param_name]
    if param_name.startswith('miceV2.'):
        param_name_split = param_name.split('.')
        if len(param_name_split) == 3:
            best_param_config['train']['preprocessing']['imputation']['arguments'][param_name_split[1]][param_name_split[2]] = param_value
        elif len(param_name_split) == 4:
            best_param_config['train']['preprocessing']['imputation']['arguments'][param_name_split[1]][param_name_split[2]][param_name_split[3]] = param_value
    else:
        #config['train']['preprocessing']['imputation']['arguments'][param_name] = param_value
        print("no arg to parse")

print(best_param_config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\alois\Desktop\Advanced ML\AML_Task_1\notebooks\hyper_tune - Copie.ipynb Cell 16 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/alois/Desktop/Advanced%20ML/AML_Task_1/notebooks/hyper_tune%20-%20Copie.ipynb#X21sZmlsZQ%3D%3D?line=19'>20</a> # Parse parameters
#      <a href='vscode-notebook-cell:/c%3A/Users/alois/Desktop/Advanced%20ML/AML_Task_1/notebooks/hyper_tune%20-%20Copie.ipynb#X21sZmlsZQ%3D%3D?line=20'>21</a> for param_name in parameters:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alois/Desktop/Advanced%20ML/AML_Task_1/notebooks/hyper_tune%20-%20Copie.ipynb#X21sZmlsZQ%3D%3D?line=21'>22</a>     param_value = best_param_config[param_name]
#      <a href='vscode-notebook-cell:/c%3A/Users/alois/Desktop/Advanced%20ML/AML_Task_1/notebooks/hyper_tune%20-%20Copie.ipynb#X21sZmlsZQ%3D%3D?line=22'>23</a>     if param_name.startswith('miceV2.'):
#      <a href='vscode-notebook-cell:/c%3A/Users/alois/Desktop/Advanced%20ML/AML_Task_1/notebooks/hyper_tune%20-%20Copie.ipynb#X21sZmlsZQ%3D%3D?line=23'>24</a>         param_name_split = param_name.split('.')
#
# TypeError: unhashable type: 'dict'

# %%
main(best_param_config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\alois\Desktop\Advanced ML\AML_Task_1\notebooks\hyper_tune - Copie.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alois/Desktop/Advanced%20ML/AML_Task_1/notebooks/hyper_tune%20-%20Copie.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> main(best_param_config)
#
# File c:\Users\alois\Desktop\Advanced ML\AML_Task_1\task1\src\train.py:176, in main(config)
#     167 subset_X_train_df, subset_y_train_df = (
#     168     X_train_df.iloc[train_idx],
#     169     y_train_df.iloc[train_idx],
#     170 )
#     171 subset_X_valid_df, subset_y_valid_df = (
#     172     X_train_df.iloc[valid_idx],
#     173     y_train_df.iloc[valid_idx],
#     174 )
# --> 176 subset_y_valid, subset_y_pred = train_and_get_prediction(
#     177     model,
#     178     subset_X_train_df,
#     179     subset_y_train_df,
#     180     subset_X_valid_df,
#     181     subset_y_valid_df,
#     182     preprocessing_config,
#     183 )
#     184 valid_score = r2_score(subset_y_valid, subset_y_pred)
#     185 scores.append(valid_score)
#
# File c:\Users\alois\Desktop\Advanced ML\AML_Task_1\task1\src\train.py:123, in train_and_get_prediction(model, X_train_df, y_train_df, X_valid_df, y_valid_df, preprocessing_config)
#     121 else:
#     122     y_valid_mat = None
# --> 123 X_train_mat, X_valid_mat, y_train_mat = preprocess_data(
#     124     X_train_df, y_train_mat, X_valid_df, preprocessing_config
#     125 )
#     126 model.fit(X_train_mat, y_train_mat)
#     128 y_pred = model.predict(X_valid_mat)
#
# File c:\Users\alois\Desktop\Advanced ML\AML_Task_1\task1\src\train.py:86, in preprocess_data(X_train_df, y, X_valid_df, preprocessing_config)
#      62 data_preprocessor = DataPreprocessor(
#      63     preprocessing_config
#      64 )
#      65 """
#      66 Preprocess feature and label data.
#      67
#    (...)
#      84     Processed feature data of valid split in numpy array format.
#      85 """
# ---> 86 X_train_mat, X_valid_mat, y_train_mat = data_preprocessor.preprocess(X_train_df, y, X_valid_df)
#      87 return X_train_mat, X_valid_mat, y_train_mat
#
# File c:\Users\alois\Desktop\Advanced ML\AML_Task_1\task1\pre\preprocessing.py:46, in DataPreprocessor.preprocess(self, X_train_df, y_train, X_valid_df)
#      44 imputation_method = self.preprocessing_config['imputation']['method']
#      45 imputation_config = self.preprocessing_config['imputation']['arguments']
# ---> 46 X_df = self.IMPUTATION[imputation_method](X_df, **imputation_config)
#      47 X_mat = X_df.to_numpy()
#      49 for step in self.preprocessing_config['execution_order']:
#
# File c:\Users\alois\Desktop\Advanced ML\AML_Task_1\task1\pre\imputation.py:115, in impute_data_with_mice_and_simple(df, estimator_params, mice_params, simple_params, num_corr_features)
#     112     feature_names = top_k_features.get_level_values(0).unique().tolist()
#     113     return feature_names
# --> 115 top_k_corr_feature_names = select_top_k_corr_features(X, k=num_corr_features)
#     117 estimator = XGBRegressor(**estimator_params)
#     118 mice_imputer = IterativeImputer(estimator=estimator, random_state=42, **mice_params)
#
# File c:\Users\alois\Desktop\Advanced ML\AML_Task_1\task1\pre\imputation.py:111, in impute_data_with_mice_and_simple.<locals>.select_top_k_corr_features(data, k)
#     109 corr_matrix = data.corr().abs()
#     110 sorted_corr = corr_matrix.unstack().sort_values(ascending=False)
# --> 111 top_k_features = sorted_corr[sorted_corr < 1].index[:k]
#     112 feature_names = top_k_features.get_level_values(0).unique().tolist()
#     113 return feature_names
#
# File c:\Users\alois\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:2129, in MultiIndex.__getitem__(self, key)
#    2126 elif isinstance(key, Index):
#    2127     key = np.asarray(key)
# -> 2129 new_codes = [level_codes[key] for level_codes in self.codes]
#    2131 return MultiIndex(
#    2132     levels=self.levels,
#    2133     codes=new_codes,
#    (...)
#    2136     verify_integrity=False,
#    2137 )
#
# File c:\Users\alois\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:2129, in <listcomp>(.0)
#    2126 elif isinstance(key, Index):
#    2127     key = np.asarray(key)
# -> 2129 new_codes = [level_codes[key] for level_codes in self.codes]
#    2131 return MultiIndex(
#    2132     levels=self.levels,
#    2133     codes=new_codes,
#    (...)
#    2136     verify_integrity=False,
#    2137 )
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
pd.read_csv('results/overview.csv').sort_values(by='train_results', ascending=False).drop_duplicates().reset_index(drop=True)
# Out:
#    train/data_paths/features train/data_paths/label  \
# 0           data/X_train.csv       data/y_train.csv
# 1           data/X_train.csv       data/y_train.csv
# 2           data/X_train.csv       data/y_train.csv
# 3           data/X_train.csv       data/y_train.csv
# 4           data/X_train.csv       data/y_train.csv
# 5           data/X_train.csv       data/y_train.csv
# 6           data/X_train.csv       data/y_train.csv
# 7           data/X_train.csv       data/y_train.csv
# 8           data/X_train.csv       data/y_train.csv
# 9           data/X_train.csv       data/y_train.csv
# 10          data/X_train.csv       data/y_train.csv
# 11          data/X_train.csv       data/y_train.csv
# 12          data/X_train.csv       data/y_train.csv
# 13          data/X_train.csv       data/y_train.csv
# 14          data/X_train.csv       data/y_train.csv
# 15          data/X_train.csv       data/y_train.csv
# 16          data/X_train.csv       data/y_train.csv
# 17          data/X_train.csv       data/y_train.csv
# 18          data/X_train.csv       data/y_train.csv
# 19          data/X_train.csv       data/y_train.csv
# 20          data/X_train.csv       data/y_train.csv
# 21          data/X_train.csv       data/y_train.csv
# 22          data/X_train.csv       data/y_train.csv
# 23          data/X_train.csv       data/y_train.csv
# 24          data/X_train.csv       data/y_train.csv
# 25          data/X_train.csv       data/y_train.csv
# 26          data/X_train.csv       data/y_train.csv
# 27          data/X_train.csv       data/y_train.csv
# 28          data/X_train.csv       data/y_train.csv
# 29          data/X_train.csv       data/y_train.csv
# 30          data/X_train.csv       data/y_train.csv
# 31          data/X_train.csv       data/y_train.csv
# 32          data/X_train.csv       data/y_train.csv
# 33          data/X_train.csv       data/y_train.csv
# 34          data/X_train.csv       data/y_train.csv
# 35          data/X_train.csv       data/y_train.csv
# 36          data/X_train.csv       data/y_train.csv
# 37          data/X_train.csv       data/y_train.csv
# 38          data/X_train.csv       data/y_train.csv
# 39          data/X_train.csv       data/y_train.csv
# 40          data/X_train.csv       data/y_train.csv
# 41          data/X_train.csv       data/y_train.csv
# 42          data/X_train.csv       data/y_train.csv
# 43          data/X_train.csv       data/y_train.csv
# 44          data/X_train.csv       data/y_train.csv
# 45          data/X_train.csv       data/y_train.csv
# 46          data/X_train.csv       data/y_train.csv
# 47          data/X_train.csv       data/y_train.csv
# 48          data/X_train.csv       data/y_train.csv
# 49          data/X_train.csv       data/y_train.csv
# 50          data/X_train.csv       data/y_train.csv
#
#     train/preprocessing/scale train/preprocessing/imputation/method  \
# 0                        True                                  mice
# 1                        True                                  mice
# 2                        True                                  mice
# 3                        True                                  mice
# 4                        True                                  mice
# 5                        True                                  mice
# 6                        True                                  mice
# 7                        True                                  mice
# 8                        True                                  mice
# 9                        True                                  mice
# 10                       True                                  mice
# 11                       True                                  mice
# 12                       True                                  mice
# 13                       True                                  mice
# 14                       True                                  mice
# 15                       True                                  mice
# 16                       True                                  mice
# 17                       True                                  mice
# 18                       True                                  mice
# 19                       True                                  mice
# 20                       True                                  mice
# 21                       True                                  mice
# 22                       True                                  mice
# 23                       True                                  mice
# 24                       True                                  mice
# 25                       True                                  mice
# 26                       True                                  mice
# 27                       True                                  mice
# 28                       True                                  mice
# 29                       True                                  mice
# 30                       True                                  mice
# 31                       True                                  mice
# 32                       True                                  mice
# 33                       True                                  mice
# 34                       True                                  mice
# 35                       True                                  mice
# 36                       True                                  mice
# 37                       True                                  mice
# 38                       True                                  mice
# 39                       True                                  mice
# 40                       True                                  mice
# 41                       True                                  mice
# 42                       True                                  mice
# 43                       True                                  mice
# 44                       True                                  mice
# 45                       True                                  mice
# 46                       True                                  mice
# 47                       True                                  mice
# 48                       True                                  mice
# 49                       True                                  mice
# 50                       True                                  mice
#
#     train/preprocessing/imputation/arguments/estimator_params/n_estimators  \
# 0                                               200.0
# 1                                               200.0
# 2                                               174.0
# 3                                               134.0
# 4                                               167.0
# 5                                               119.0
# 6                                               134.0
# 7                                               130.0
# 8                                                91.0
# 9                                                50.0
# 10                                              113.0
# 11                                               50.0
# 12                                               50.0
# 13                                              197.0
# 14                                               65.0
# 15                                               86.0
# 16                                               80.0
# 17                                               96.0
# 18                                               50.0
# 19                                              100.0
# 20                                              139.0
# 21                                               78.0
# 22                                              200.0
# 23                                              103.0
# 24                                              200.0
# 25                                              143.0
# 26                                              109.0
# 27                                               50.0
# 28                                              200.0
# 29                                               50.0
# 30                                               50.0
# 31                                              200.0
# 32                                              150.0
# 33                                               66.0
# 34                                              103.0
# 35                                              200.0
# 36                                               92.0
# 37                                              113.0
# 38                                              192.0
# 39                                              149.0
# 40                                              122.0
# 41                                               53.0
# 42                                               63.0
# 43                                               50.0
# 44                                              193.0
# 45                                              144.0
# 46                                              117.0
# 47                                               50.0
# 48                                              121.0
# 49                                              200.0
# 50                                               50.0
#
#     train/preprocessing/imputation/arguments/estimator_params/max_depth  \
# 0                                                 9.0
# 1                                                 2.0
# 2                                                 7.0
# 3                                                10.0
# 4                                                 9.0
# 5                                                 2.0
# 6                                                 7.0
# 7                                                 7.0
# 8                                                 2.0
# 9                                                 6.0
# 10                                                5.0
# 11                                                9.0
# 12                                                2.0
# 13                                                2.0
# 14                                               10.0
# 15                                                4.0
# 16                                                5.0
# 17                                                6.0
# 18                                                8.0
# 19                                                5.0
# 20                                                3.0
# 21                                                2.0
# 22                                               10.0
# 23                                                7.0
# 24                                                9.0
# 25                                                2.0
# 26                                                2.0
# 27                                                4.0
# 28                                                6.0
# 29                                               10.0
# 30                                                6.0
# 31                                               10.0
# 32                                                5.0
# 33                                                4.0
# 34                                               10.0
# 35                                                4.0
# 36                                                9.0
# 37                                                7.0
# 38                                                7.0
# 39                                                5.0
# 40                                                8.0
# 41                                                7.0
# 42                                                7.0
# 43                                                8.0
# 44                                                7.0
# 45                                                3.0
# 46                                                4.0
# 47                                                7.0
# 48                                                3.0
# 49                                               10.0
# 50                                                2.0
#
#     train/preprocessing/imputation/arguments/mice_params/max_iter  \
# 0                                                 6.0
# 1                                                 8.0
# 2                                                 7.0
# 3                                                 5.0
# 4                                                 9.0
# 5                                                16.0
# 6                                                20.0
# 7                                                 5.0
# 8                                                 9.0
# 9                                                 5.0
# 10                                               18.0
# 11                                               11.0
# 12                                               19.0
# 13                                                5.0
# 14                                               11.0
# 15                                               15.0
# 16                                               20.0
# 17                                               17.0
# 18                                                5.0
# 19                                               10.0
# 20                                               17.0
# 21                                               17.0
# 22                                                9.0
# 23                                               11.0
# 24                                                5.0
# 25                                               19.0
# 26                                                6.0
# 27                                               18.0
# 28                                               20.0
# 29                                                8.0
# 30                                                5.0
# 31                                               20.0
# 32                                                7.0
# 33                                               14.0
# 34                                               20.0
# 35                                                5.0
# 36                                                8.0
# 37                                               10.0
# 38                                               20.0
# 39                                               13.0
# 40                                               15.0
# 41                                                6.0
# 42                                               11.0
# 43                                               20.0
# 44                                               20.0
# 45                                               14.0
# 46                                               12.0
# 47                                               13.0
# 48                                               17.0
# 49                                               20.0
# 50                                               19.0
#
#    train/preprocessing/imputation/arguments/mice_params/imputation_order  \
# 0                                          descending
# 1                                           ascending
# 2                                           ascending
# 3                                           ascending
# 4                                              arabic
# 5                                          descending
# 6                                           ascending
# 7                                          descending
# 8                                          descending
# 9                                          descending
# 10                                          ascending
# 11                                             arabic
# 12                                          ascending
# 13                                          ascending
# 14                                         descending
# 15                                         descending
# 16                                          ascending
# 17                                         descending
# 18                                         descending
# 19                                         descending
# 20                                         descending
# 21                                          ascending
# 22                                          ascending
# 23                                             arabic
# 24                                             random
# 25                                          ascending
# 26                                          ascending
# 27                                             random
# 28                                          ascending
# 29                                             arabic
# 30                                          ascending
# 31                                              roman
# 32                                              roman
# 33                                         descending
# 34                                         descending
# 35                                             random
# 36                                             random
# 37                                          ascending
# 38                                         descending
# 39                                             random
# 40                                             random
# 41                                             random
# 42                                         descending
# 43                                             random
# 44                                             arabic
# 45                                             arabic
# 46                                             random
# 47                                          ascending
# 48                                             arabic
# 49                                             random
# 50                                             arabic
#
#    train/preprocessing/imputation/arguments/simple_params/strategy  \
# 0                                                mean
# 1                                                mean
# 2                                                mean
# 3                                              median
# 4                                            constant
# 5                                                mean
# 6                                                mean
# 7                                            constant
# 8                                            constant
# 9                                            constant
# 10                                               mean
# 11                                           constant
# 12                                               mean
# 13                                               mean
# 14                                             median
# 15                                           constant
# 16                                               mean
# 17                                             median
# 18                                               mean
# 19                                               mean
# 20                                           constant
# 21                                               mean
# 22                                               mean
# 23                                               mean
# 24                                           constant
# 25                                           constant
# 26                                           constant
# 27                                             median
# 28                                               mean
# 29                                           constant
# 30                                           constant
# 31                                               mean
# 32                                      most_frequent
# 33                                           constant
# 34                                      most_frequent
# 35                                      most_frequent
# 36                                      most_frequent
# 37                                               mean
# 38                                      most_frequent
# 39                                               mean
# 40                                           constant
# 41                                             median
# 42                                               mean
# 43                                           constant
# 44                                             median
# 45                                      most_frequent
# 46                                             median
# 47                                      most_frequent
# 48                                      most_frequent
# 49                                           constant
# 50                                           constant
#
#     train/preprocessing/imputation/arguments/num_corr_features  ...  \
# 0                                                12.0           ...
# 1                                                 5.0           ...
# 2                                                12.0           ...
# 3                                                 7.0           ...
# 4                                                15.0           ...
# 5                                                 5.0           ...
# 6                                                15.0           ...
# 7                                                14.0           ...
# 8                                                 5.0           ...
# 9                                                12.0           ...
# 10                                               14.0           ...
# 11                                               13.0           ...
# 12                                                5.0           ...
# 13                                                5.0           ...
# 14                                               14.0           ...
# 15                                                8.0           ...
# 16                                               15.0           ...
# 17                                               13.0           ...
# 18                                                7.0           ...
# 19                                               10.0           ...
# 20                                                8.0           ...
# 21                                                9.0           ...
# 22                                               11.0           ...
# 23                                               15.0           ...
# 24                                               15.0           ...
# 25                                                5.0           ...
# 26                                               15.0           ...
# 27                                                5.0           ...
# 28                                                6.0           ...
# 29                                               15.0           ...
# 30                                               10.0           ...
# 31                                               15.0           ...
# 32                                               11.0           ...
# 33                                               10.0           ...
# 34                                               12.0           ...
# 35                                               11.0           ...
# 36                                                7.0           ...
# 37                                               12.0           ...
# 38                                               12.0           ...
# 39                                               14.0           ...
# 40                                               13.0           ...
# 41                                                8.0           ...
# 42                                               12.0           ...
# 43                                               15.0           ...
# 44                                                8.0           ...
# 45                                               11.0           ...
# 46                                               11.0           ...
# 47                                                6.0           ...
# 48                                               11.0           ...
# 49                                               15.0           ...
# 50                                                5.0           ...
#
#    train/model_type train/model_config/kernel  train/model_config/gamma  \
# 0               krr                       rbf                  0.004307
# 1               krr                       rbf                  0.006216
# 2               krr                       rbf                  0.006247
# 3               krr                       rbf                  0.006037
# 4               krr                       rbf                  0.004635
# 5               krr                       rbf                  0.004141
# 6               krr                       rbf                  0.004570
# 7               krr                       rbf                  0.002951
# 8               krr                       rbf                  0.005537
# 9               krr                       rbf                  0.006071
# 10              krr                       rbf                  0.002807
# 11              krr                       rbf                  0.003876
# 12              krr                       rbf                  0.004029
# 13              krr                       rbf                  0.007506
# 14              krr                       rbf                  0.007817
# 15              krr                       rbf                  0.002626
# 16              krr                       rbf                  0.006850
# 17              krr                       rbf                  0.002843
# 18              krr                       rbf                  0.009088
# 19              krr                       rbf                  0.005000
# 20              krr                       rbf                  0.001436
# 21              krr                       rbf                  0.005516
# 22              krr                       rbf                  0.001724
# 23              krr                       rbf                  0.001932
# 24              krr                       rbf                  0.001550
# 25              krr                       rbf                  0.001000
# 26              krr                       rbf                  0.001000
# 27              krr                       rbf                  0.001000
# 28              krr                       rbf                  0.001152
# 29              krr                       rbf                  0.001110
# 30              krr                       rbf                  0.001000
# 31              krr                       rbf                  0.001000
# 32              krr                       rbf                  0.001996
# 33              krr                       rbf                  0.007786
# 34              krr                       rbf                  0.001532
# 35              krr                       rbf                  0.001000
# 36              krr                       rbf                  0.003431
# 37              krr                       rbf                  0.009006
# 38              krr                       rbf                  0.003667
# 39              krr                       rbf                  0.009349
# 40              krr                       rbf                  0.006863
# 41              krr                       rbf                  0.006300
# 42              krr                       rbf                  0.006999
# 43              krr                       rbf                  0.010000
# 44              krr                       rbf                  0.008711
# 45              krr                       rbf                  0.002668
# 46              krr                       rbf                  0.004902
# 47              krr                       rbf                  0.010000
# 48              krr                       rbf                  0.007052
# 49              krr                       rbf                  0.001000
# 50              krr                       rbf                  0.009450
#
#    train/model_config/alpha train/cross_validation    train/results_path  \
# 0                       0.1                    5.0  results/overview.csv
# 1                       0.2                    5.0  results/overview.csv
# 2                       0.1                    5.0  results/overview.csv
# 3                       0.2                    5.0  results/overview.csv
# 4                       0.1                    5.0  results/overview.csv
# 5                       0.4                    5.0  results/overview.csv
# 6                       0.4                    5.0  results/overview.csv
# 7                       0.2                    5.0  results/overview.csv
# 8                       0.7                    5.0  results/overview.csv
# 9                       0.3                    5.0  results/overview.csv
# 10                      0.3                    5.0  results/overview.csv
# 11                      0.6                    5.0  results/overview.csv
# 12                      0.7                    5.0  results/overview.csv
# 13                      0.1                    5.0  results/overview.csv
# 14                      0.7                    5.0  results/overview.csv
# 15                      0.4                    5.0  results/overview.csv
# 16                      0.4                    5.0  results/overview.csv
# 17                      0.9                    5.0  results/overview.csv
# 18                      0.1                    5.0  results/overview.csv
# 19                      0.5                    5.0  results/overview.csv
# 20                      0.2                    5.0  results/overview.csv
# 21                      0.3                    5.0  results/overview.csv
# 22                      0.4                    5.0  results/overview.csv
# 23                      0.8                    5.0  results/overview.csv
# 24                      0.9                    5.0  results/overview.csv
# 25                      0.5                    5.0  results/overview.csv
# 26                      1.0                    5.0  results/overview.csv
# 27                      0.8                    5.0  results/overview.csv
# 28                      1.0                    5.0  results/overview.csv
# 29                      0.5                    5.0  results/overview.csv
# 30                      1.0                    5.0  results/overview.csv
# 31                      1.0                    5.0  results/overview.csv
# 32                      0.1                    5.0  results/overview.csv
# 33                      0.8                    5.0  results/overview.csv
# 34                      0.4                    5.0  results/overview.csv
# 35                      0.3                    5.0  results/overview.csv
# 36                      1.0                    5.0  results/overview.csv
# 37                      0.7                    5.0  results/overview.csv
# 38                      0.9                    5.0  results/overview.csv
# 39                      0.7                    5.0  results/overview.csv
# 40                      0.2                    5.0  results/overview.csv
# 41                      0.1                    5.0  results/overview.csv
# 42                      0.0                    5.0  results/overview.csv
# 43                      0.0                    5.0  results/overview.csv
# 44                      0.1                    5.0  results/overview.csv
# 45                      0.0                    5.0  results/overview.csv
# 46                      0.3                    5.0  results/overview.csv
# 47                      0.3                    5.0  results/overview.csv
# 48                      0.0                    5.0  results/overview.csv
# 49                      0.0                    5.0  results/overview.csv
# 50                      0.4                    5.0  results/overview.csv
#
#     evaluate/run  evaluate/data_paths/features  evaluate/data_paths/label  \
# 0           True               data/X_test.csv        data/y_test_rbf.csv
# 1           True               data/X_test.csv        data/y_test_rbf.csv
# 2           True               data/X_test.csv        data/y_test_rbf.csv
# 3           True               data/X_test.csv        data/y_test_rbf.csv
# 4           True               data/X_test.csv        data/y_test_rbf.csv
# 5           True               data/X_test.csv        data/y_test_rbf.csv
# 6           True               data/X_test.csv        data/y_test_rbf.csv
# 7           True               data/X_test.csv        data/y_test_rbf.csv
# 8           True               data/X_test.csv        data/y_test_rbf.csv
# 9           True               data/X_test.csv        data/y_test_rbf.csv
# 10          True               data/X_test.csv        data/y_test_rbf.csv
# 11          True               data/X_test.csv        data/y_test_rbf.csv
# 12          True               data/X_test.csv        data/y_test_rbf.csv
# 13          True               data/X_test.csv        data/y_test_rbf.csv
# 14          True               data/X_test.csv        data/y_test_rbf.csv
# 15          True               data/X_test.csv        data/y_test_rbf.csv
# 16          True               data/X_test.csv        data/y_test_rbf.csv
# 17          True               data/X_test.csv        data/y_test_rbf.csv
# 18          True               data/X_test.csv        data/y_test_rbf.csv
# 19          True               data/X_test.csv        data/y_test_rbf.csv
# 20          True               data/X_test.csv        data/y_test_rbf.csv
# 21          True               data/X_test.csv        data/y_test_rbf.csv
# 22          True               data/X_test.csv        data/y_test_rbf.csv
# 23          True               data/X_test.csv        data/y_test_rbf.csv
# 24          True               data/X_test.csv        data/y_test_rbf.csv
# 25          True               data/X_test.csv        data/y_test_rbf.csv
# 26          True               data/X_test.csv        data/y_test_rbf.csv
# 27          True               data/X_test.csv        data/y_test_rbf.csv
# 28          True               data/X_test.csv        data/y_test_rbf.csv
# 29          True               data/X_test.csv        data/y_test_rbf.csv
# 30          True               data/X_test.csv        data/y_test_rbf.csv
# 31          True               data/X_test.csv        data/y_test_rbf.csv
# 32          True               data/X_test.csv        data/y_test_rbf.csv
# 33          True               data/X_test.csv        data/y_test_rbf.csv
# 34          True               data/X_test.csv        data/y_test_rbf.csv
# 35          True               data/X_test.csv        data/y_test_rbf.csv
# 36          True               data/X_test.csv        data/y_test_rbf.csv
# 37          True               data/X_test.csv        data/y_test_rbf.csv
# 38          True               data/X_test.csv        data/y_test_rbf.csv
# 39          True               data/X_test.csv        data/y_test_rbf.csv
# 40          True               data/X_test.csv        data/y_test_rbf.csv
# 41          True               data/X_test.csv        data/y_test_rbf.csv
# 42          True               data/X_test.csv        data/y_test_rbf.csv
# 43          True               data/X_test.csv        data/y_test_rbf.csv
# 44          True               data/X_test.csv        data/y_test_rbf.csv
# 45          True               data/X_test.csv        data/y_test_rbf.csv
# 46          True               data/X_test.csv        data/y_test_rbf.csv
# 47          True               data/X_test.csv        data/y_test_rbf.csv
# 48          True               data/X_test.csv        data/y_test_rbf.csv
# 49          True               data/X_test.csv        data/y_test_rbf.csv
# 50          True               data/X_test.csv        data/y_test_rbf.csv
#
#    train_results
# 0       0.449828
# 1       0.449525
# 2       0.444121
# 3       0.443323
# 4       0.441701
# 5       0.438186
# 6       0.435293
# 7       0.431519
# 8       0.430190
# 9       0.427068
# 10      0.426889
# 11      0.426835
# 12      0.425790
# 13      0.421651
# 14      0.413265
# 15      0.413201
# 16      0.409127
# 17      0.406654
# 18      0.403058
# 19      0.395271
# 20      0.392407
# 21      0.391646
# 22      0.390993
# 23      0.383597
# 24      0.374115
# 25      0.370152
# 26      0.369261
# 27      0.368237
# 28      0.367848
# 29      0.363904
# 30      0.361725
# 31      0.357010
# 32      0.348884
# 33      0.328725
# 34      0.322439
# 35      0.273981
# 36      0.209883
# 37      0.168698
# 38      0.162789
# 39      0.143819
# 40      0.024493
# 41      0.024298
# 42     -0.029702
# 43     -0.046002
# 44     -0.209819
# 45     -0.722402
# 46     -1.163973
# 47     -1.265277
# 48     -6.136740
# 49     -7.880099
# 50    -51.369771
#
# [51 rows x 24 columns]
